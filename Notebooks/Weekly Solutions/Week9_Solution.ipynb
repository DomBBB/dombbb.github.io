# %% [markdown]
# # Notebook 8

# %% [markdown]
# Import useful libraries.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import seaborn as sns

# %% [markdown]
# Create a Matplotlib plot with a figure size of 10x10 (inches). Hint: Use the subplots() function.
#
# Now add a line plot with corresponding points x=[3, 2, 1, 0, -1, -2, -3] and y=[9, 4, 1, 0, 1, 4, 9], red color and the label "square function".
#
# Then make sure the legend is shown.
#
# Finally print the plot.

# %%
fig, ax = plt.subplots(figsize=(10, 10))
ax.plot([3, 2, 1, 0, -1, -2, -3], [9, 4, 1, 0, 1, 4, 9], color="red", label="square function")
ax.legend()
plt.show()

# %% [markdown]
# Copy the code from above and adapt it so that it shows a second line plot with corresponding points x=[3, 2, 1, 0, -1, -2, -3] and y=[9, 4, 1, 0, -1, -4, -9], blue color and the label "other function".

# %%
fig, ax = plt.subplots(figsize=(10, 10))
ax.plot([3, 2, 1, 0, -1, -2, -3], [9, 4, 1, 0, 1, 4, 9], color="red", label="square function")
ax.plot([3, 2, 1, 0, -1, -2, -3], [9, 4, 1, 0, -1, -4, -9], color="blue", label="other function")
ax.legend()
plt.show()

# %% [markdown]
# Use the same code for a bar plot and set the width of the bars to 0.5.

# %%
fig, ax = plt.subplots(figsize=(10, 10))
ax.bar([3, 2, 1, 0, -1, -2, -3], [9, 4, 1, 0, 1, 4, 9], width=0.5, color="red", label="square function")
ax.bar([3, 2, 1, 0, -1, -2, -3], [9, 4, 1, 0, -1, -4, -9], width=0.5, color="blue", label="other function")
ax.legend()
plt.show()

# %% [markdown]
# Now create 6 subplots (3 rows and 2 columns). Use the 3 codes from above for the plots (1, 1), (2, 1) and (3,2).

# %%
fig, axes = plt.subplots(3, 2, figsize=(10, 10))

axes[0][0].plot([3, 2, 1, 0, -1, -2, -3], [9, 4, 1, 0, 1, 4, 9], color="red", label="square function")
axes[0][0].legend()

axes[1][0].plot([3, 2, 1, 0, -1, -2, -3], [9, 4, 1, 0, 1, 4, 9], color="red", label="square function")
axes[1][0].plot([3, 2, 1, 0, -1, -2, -3], [9, 4, 1, 0, -1, -4, -9], color="blue", label="other function")
axes[1][0].legend()

axes[2][1].bar([3, 2, 1, 0, -1, -2, -3], [9, 4, 1, 0, 1, 4, 9], width=0.5, color="red", label="square function")
axes[2][1].bar([3, 2, 1, 0, -1, -2, -3], [9, 4, 1, 0, -1, -4, -9], width=0.5, color="blue", label="other function")
axes[2][1].legend()

plt.show()

# %% [markdown]
# Copy the code from above and use the sharex=True parameter.

# %%
fig, axes = plt.subplots(3, 2, sharex=True, figsize=(10, 10))

axes[0][0].plot([3, 2, 1, 0, -1, -2, -3], [9, 4, 1, 0, 1, 4, 9], color="red", label="square function")
axes[0][0].legend()

axes[1][0].plot([3, 2, 1, 0, -1, -2, -3], [9, 4, 1, 0, 1, 4, 9], color="red", label="square function")
axes[1][0].plot([3, 2, 1, 0, -1, -2, -3], [9, 4, 1, 0, -1, -4, -9], color="blue", label="other function")
axes[1][0].legend()

axes[2][1].bar([3, 2, 1, 0, -1, -2, -3], [9, 4, 1, 0, 1, 4, 9], width=0.5, color="red", label="square function")
axes[2][1].bar([3, 2, 1, 0, -1, -2, -3], [9, 4, 1, 0, -1, -4, -9], width=0.5, color="blue", label="other function")
axes[2][1].legend()

plt.show()

# %% [markdown]
# Copy the code from above but now use the sharey=True parameter instead of sharex.

# %%
fig, axes = plt.subplots(3, 2, sharey=True, figsize=(10, 10))

axes[0][0].plot([3, 2, 1, 0, -1, -2, -3], [9, 4, 1, 0, 1, 4, 9], color="red", label="square function")
axes[0][0].legend()

axes[1][0].plot([3, 2, 1, 0, -1, -2, -3], [9, 4, 1, 0, 1, 4, 9], color="red", label="square function")
axes[1][0].plot([3, 2, 1, 0, -1, -2, -3], [9, 4, 1, 0, -1, -4, -9], color="blue", label="other function")
axes[1][0].legend()

axes[2][1].bar([3, 2, 1, 0, -1, -2, -3], [9, 4, 1, 0, 1, 4, 9], width=0.5, color="red", label="square function")
axes[2][1].bar([3, 2, 1, 0, -1, -2, -3], [9, 4, 1, 0, -1, -4, -9], width=0.5, color="blue", label="other function")
axes[2][1].legend()

plt.show()

# %% [markdown]
# Copy the code from above and adapt it so it is plotted with Seaborn. Hint: Omit the width parameter in the barplot.

# %%
fig, axes = plt.subplots(3, 2, sharey=True, figsize=(10, 10))

sns.lineplot(x=[3, 2, 1, 0, -1, -2, -3], y=[9, 4, 1, 0, 1, 4, 9], color="red", label="square function", ax=axes[0][0])

sns.lineplot(x=[3, 2, 1, 0, -1, -2, -3], y=[9, 4, 1, 0, 1, 4, 9], color="red", label="square function", ax=axes[1][0])
sns.lineplot(x=[3, 2, 1, 0, -1, -2, -3], y=[9, 4, 1, 0, -1, -4, -9], color="blue", label="other function", ax=axes[1][0])

sns.barplot(x=[3, 2, 1, 0, -1, -2, -3], y=[9, 4, 1, 0, 1, 4, 9], color="red", label="square function", ax=axes[2][1])
sns.barplot(x=[3, 2, 1, 0, -1, -2, -3], y=[9, 4, 1, 0, -1, -4, -9], color="blue", label="other function", ax=axes[2][1])

plt.show()
